# %%
print("hello")
# Out:
# hello

# %%
import blurhash
import PIL.Image
import numpy

img = "lcp/blurhash/images/MoonMasterpiece_LunarNewYearCollection_M-1.jpg"
PIL.Image.open(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x596 at 0x7F9DC0599470>

# %%
print(img)
# blurhash.encode(numpy.array(PIL.Image.open(img).convert("RGB")))
# Out:
# lcp/blurhash/images/MoonMasterpiece_LunarNewYearCollection_M-1.jpg

# %%
blurhash.encode(numpy.array(PIL.Image.open(img).convert("RGB")))
# Out:
# 'UFI_=y#SqHt8#6oLs8OArFr]yCo#-:J5D+sX'

# %%
PIL.Image.fromarray(numpy.array(blurhash.decode('UFI_=y#SqHt8#6oLs8OArFr]yCo#-:J5D+sX', 800, 361)).astype('uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=800x361 at 0x7F9DC0599E48>
