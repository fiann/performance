# %%
print("hello")
# Out:
# hello

# %%
import blurhash
import PIL.Image
import numpy

img = "lcp/blurhash/images/MoonMasterpiece_LunarNewYearCollection_M-1.jpg"
PIL.Image.open(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x722 at 0x7F9DC0599F60>

# %%
print(img)
# blurhash.encode(numpy.array(PIL.Image.open(img).convert("RGB")))
# Out:
# lcp/blurhash/images/MoonMasterpiece_LunarNewYearCollection.jpg

# %%
blurhash.encode(numpy.array(PIL.Image.open(img).convert("RGB")))
# Out:
# 'UDJErHujZiqEvfxvSvNfxHR%tRMy%yIVVs?Z'

# %%
PIL.Image.fromarray(numpy.array(blurhash.decode('UDJErHujZiqEvfxvSvNfxHR%tRMy%yIVVs?Z', 800, 361)).astype('uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=800x361 at 0x7F9DC05990F0>
